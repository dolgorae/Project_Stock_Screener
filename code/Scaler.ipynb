# %%
import pandas as pd
import os
import numpy as np
import csv
import math

# %%
fin_path ='C:/Users/eaststate/Desktop/스마/재무'
fin_file = os.listdir(fin_path)

fin_file_path = []
for i in fin_file:
    fin_file_path.append(fin_path+"/"+i)
# Out:
# Empty DataFrame
# Columns: [종목코드, 해당년도, 매출증감비율, 영업이익증감비율, 당기순이익증감비율, 자산총계증감비율, 부채비율, 부채증감비율, PBR, PER, log(PBR증감비율), OPM, 자본유보율, ROE, ROA, 현금배당성향]
# Index: []

# %%
fin_df = pd.read_csv(fin_file_path[199],encoding='cp949', thousands=',')
fin_df
# Out:
#             항목       2015/12     2016/12     2017/12     2018/12  2019/12  \
# 0          매출액  2.270830e+05         NaN         NaN         NaN      NaN
# 1         영업이익  2.800000e+04    23997.00    24418.00    25366.00      NaN
# 2   영업이익(발표기준)  2.800000e+04         NaN         NaN         NaN      NaN
# 3     세전계속사업이익  2.723000e+04    23714.00    24455.00    25435.00      NaN
# 4        당기순이익  2.037600e+04    18078.00    18790.00    19695.00      NaN
# 5    당기순이익(지배)  1.872200e+04    16320.00    16680.00    17369.00      NaN
# 6   당기순이익(비지배)  1.654000e+03         NaN         NaN         NaN      NaN
# 7         자산총계  3.619807e+06  3782670.00  3933663.00  4074642.00      NaN
# 8         부채총계  3.364884e+06  3519435.00  3655459.00  3780576.00      NaN
# 9         자본총계  2.549230e+05   263234.00   278202.00   292482.00      NaN
# 10    자본총계(지배)  2.151040e+05   225660.00   240507.00   255596.00      NaN
# 11   자본총계(비지배)           NaN         NaN         NaN         NaN      NaN
# 12         자본금  3.611300e+04    36562.00    36776.00    36942.00      NaN
# 13    영업활동현금흐름  1.870300e+04         NaN         NaN         NaN      NaN
# 14    투자활동현금흐름 -8.588100e+04         NaN         NaN         NaN      NaN
# 15    재무활동현금흐름  6.171000e+04         NaN         NaN         NaN      NaN
# 16       CAPEX  4.295000e+03         NaN         NaN         NaN      NaN
# 17         FCF           NaN         NaN         NaN         NaN      NaN
# 18      이자발생부채  4.914540e+05         NaN         NaN         NaN      NaN
# 19       영업이익률  1.233000e+01         NaN         NaN         NaN      NaN
# 20        순이익률  8.970000e+00         NaN         NaN         NaN      NaN
# 21      ROE(%)  7.410000e+00        7.16        7.00         NaN      NaN
# 22      ROA(%)  4.900000e-01        0.49        0.49         NaN      NaN
# 23        부채비율  1.319960e+03     1337.00     1313.96     1292.58      NaN
# 24       자본유보율  6.059000e+02         NaN         NaN         NaN      NaN
# 25      EPS(원)  2.776000e+03     2260.00     2309.00     2405.00      NaN
# 26      PER(배)  4.180000e+00        3.55        3.48        3.34      NaN
# 27      BPS(원)  2.978200e+04    31243.00    33299.00    35388.00      NaN
# 28      PBR(배)  3.900000e-01        0.26        0.24        0.23      NaN
# 29    현금DPS(원)  7.000000e+02      622.00      642.00      672.00      NaN
# 30     현금배당수익률  6.030000e+00        7.74        8.00        8.37      NaN
# 31   현금배당성향(%)  2.700000e+01       27.52       27.81       27.95      NaN
# 32  발행주식수(보통주)  7.222677e+08         NaN         NaN         NaN      NaN
#
#     2020/12(E)  2021/12(E)  2022/12(E)
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN

# %%
price_path ='C:/Users/eaststate/Desktop/스마/stock_value'
price_file = os.listdir(price_path)

price_file_path = []
for i in price_file:
    price_file_path.append(price_path+"/"+i)
price_df = pd.read_csv(price_file_path[0],encoding='utf-8',index_col=0)


change_list = ['종목코드','170401-180331','180401-190331','190401-200331']

change_df = pd.DataFrame(columns=change_list)

for i in range(len(price_file_path)):
    title = price_file_path[i]
    price_df = pd.read_csv(title,encoding='utf-8',index_col=0)
    change_dict={}
    for p in range(price_df.shape[0]):
        date= price_df.iloc[p,0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-52e97d6cf51c> in <module>
#      20     change_dict={}
#      21     for p in range(price_df.shape[0]):
# ---> 22         date= price_df.iloc[p,0]
#      23
#      24 date
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2092         self._has_valid_tuple(tup)
#    2093         try:
# -> 2094             return self._getitem_lowerdim(tup)
#    2095         except IndexingError:
#    2096             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     927         for i, key in enumerate(tup):
#     928             if is_label_like(key) or isinstance(key, tuple):
# --> 929                 section = self._getitem_axis(key, axis=i)
#     930
#     931                 # we have yielded a scalar ?
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2157             self._validate_integer(key, axis)
#    2158
# -> 2159             return self._get_loc(key, axis=axis)
#    2160
#    2161     # raise_missing is included for compat with the parent class signature
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_loc(self, key, axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
# --> 163         return self.obj._ixs(key, axis=axis)
#     164
#     165     def _slice(self, obj, axis: int, kind=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2913         if axis == 0:
#    2914             label = self.index[i]
# -> 2915             new_values = self._data.fast_xs(i)
#    2916             if is_scalar(new_values):
#    2917                 return new_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in fast_xs(self, loc)
#     897
#     898         # unique
# --> 899         dtype = _interleaved_dtype(self.blocks)
#     900
#     901         n = len(items)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleaved_dtype(blocks)
#    1896         return None
#    1897
# -> 1898     return find_common_type([b.dtype for b in blocks])
#    1899
#    1900
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in find_common_type(types)
#    1156     # don't mix bool / int or float or complex
#    1157     # this is different from numpy, which casts bool with float/int as int
# -> 1158     has_bools = any(is_bool_dtype(t) for t in types)
#    1159     if has_bools:
#    1160         for t in types:
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in <genexpr>(.0)
#    1156     # don't mix bool / int or float or complex
#    1157     # this is different from numpy, which casts bool with float/int as int
# -> 1158     has_bools = any(is_bool_dtype(t) for t in types)
#    1159     if has_bools:
#    1160         for t in types:
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\common.py in is_bool_dtype(arr_or_dtype)
#    1675         # guess this
#    1676         return arr_or_dtype.is_object and arr_or_dtype.inferred_type == "boolean"
# -> 1677     elif is_extension_array_dtype(arr_or_dtype):
#    1678         dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
#    1679         return dtype._is_boolean
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\common.py in is_extension_array_dtype(arr_or_dtype)
#    1786     False
#    1787     """
# -> 1788     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
#    1789     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1790
#
# KeyboardInterrupt:

# %%
price_path ='C:/Users/eaststate/Desktop/스마/stock_value'
price_file = os.listdir(price_path)

price_file_path = []
for i in price_file:
    price_file_path.append(price_path+"/"+i)
price_df = pd.read_csv(price_file_path[0],encoding='utf-8',index_col=0)


annual_price_list = ['종목코드','2015','2016','2017','2018','2019','2020']

annual_price_df = pd.DataFrame(columns=annual_price_list)

date_list_0331=[]
date_list_0330=[]
date_list_0401=[]
for i in range(2015,2021):
    date_list_0331.append(str(i)+'.03.31')
    date_list_0330.append(str(i)+'.03.30')
    date_list_0401.append(str(i)+'.04.01')
#

for i in range(len(price_file_path)):
    title = price_file_path[i]
    price_df = pd.read_csv(title,encoding='utf-8',index_col=0)
    change_dict={}

    for p in range(price_df.shape[0]):
        date= price_df.iloc[p,0]
        if date in date_list_0331:
            change_dict[date] = price_df.iloc[p,1]
        elif date in date_list_0330:
            change_dict[date] = price_df.iloc[p,1]
        elif date in date_list_0401:
            change_dict[date] = price_df.iloc[p,1]
    temp_dict=change_dict
    new_dict={}
    for s in range(2015,2021):
        for q in temp_dict:
            if str(s) in q:
                new_dict[q] = temp_dict[q]
                break
    row_list=[]
    row_list.append(price_file[i][0:6])
    for i in range(2015,2021):
        var = np.nan
        for p in new_dict:
            if str(i) in p:
                var =new_dict[p]
        row_list.append(var)
    annual_price_df.loc[len(annual_price_df)] = row_list

annual_price_df
# Out:
#        종목코드      2015      2016      2017      2018      2019      2020
# 0    000070   91000.0  157500.0  123500.0   98000.0   83500.0   41350.0
# 1    000080   22100.0   26950.0   20350.0   22450.0   18350.0   26950.0
# 2    000100  200000.0  281000.0  222500.0  222000.0  241500.0  224500.0
# 3    000120  195000.0  187000.0  166500.0  137500.0  169500.0  128000.0
# 4    000150  108500.0   85700.0   94700.0  106500.0   96100.0   35000.0
# ..      ...       ...       ...       ...       ...       ...       ...
# 195  282330       NaN       NaN       NaN  169000.0  211000.0  127500.0
# 196  285130       NaN       NaN       NaN  105000.0   70400.0   81500.0
# 197  294870       NaN       NaN       NaN       NaN   51200.0   15700.0
# 198  298040       NaN       NaN       NaN       NaN   41450.0   13150.0
# 199  316140       NaN       NaN       NaN       NaN   14150.0    7270.0
#
# [200 rows x 7 columns]

# %%
change_price_list = ['종목코드','15-16','16-17','17-18','18-19','19-20']

change_price_df = pd.DataFrame(columns=change_price_list)

line= annual_price_df.shape[0]
for i in range(line):
    temp_df = annual_price_df.loc[i]
    change_row_list=[]
    change_row_list.append(temp_df.iloc[0])
    for i in range(1,6):
        a = temp_df.iloc[i]
        b = temp_df.iloc[i+1]
        c = b/a
        change_row_list.append(c)
    change_price_df.loc[len(change_price_df)] = change_row_list

change_price_df.to_csv('change_price_df.csv',encoding='utf-8')

# %%
group_price_list = ['종목코드','15-16','16-17','17-18','18-19','19-20']

group_price_df = pd.DataFrame(columns=group_price_list)

line_change= change_price_df.shape[0]

for i in range(line_change):
    temp_df = change_price_df.loc[i]
    group_row_list=[]
    group_row_list.append(temp_df.iloc[0])
    for i in range(1,6):
        a = temp_df.iloc[i]
        if a >1.15:
            binary = 2
        elif a > 1:
            binary = 1
        elif a<1:
            binary =0
        else:
            binary = np.nan
            
        group_row_list.append(binary)
    group_price_df.loc[len(group_price_df)] = group_row_list

group_price_df.to_csv('group_price_df.csv',encoding='utf-8')

# %%
bal_list = ['종목코드','해당년도','매출증감비율','영업이익증감비율','당기순이익증감비율','자산총계증감비율','부채비율','부채증감비율','PBR','PER','log(PBR증감비율)','OPM','자본유보율','ROE','ROA','현금배당성향']
bal_df = pd.DataFrame(columns=bal_list)


bal_df
    
    

year_list=['2016/12','2017/12','2018/12','2019/12']

for q in range(len(fin_file_path)):
    fin_df = pd.read_csv(fin_file_path[q],encoding='cp949',index_col=1,skiprows=[0], thousands=',')
    fin_df= fin_df.iloc[:,1:8]
    for i in range(len(year_list)):
        append_list =[]
        stock_code = fin_file[q][0:6]
        stock_code = stock_code.replace('.csv','')
        append_list.append(stock_code)
        temp_list = append_list
        temp_list.append(year_list[i])
        mean_asset = (fin_df.iloc[7,i]+fin_df.iloc[7,i+1])/2
        sales_shift= (fin_df.iloc[0,i+1]-fin_df.iloc[0,i])/mean_asset
        operating_revenue_shift= (fin_df.iloc[2,i+1]-fin_df.iloc[2,i])/mean_asset
        net_revenue_shift= (fin_df.iloc[4,i+1] -fin_df.iloc[4,i])/mean_asset
        asset_shift_ratio=fin_df.iloc[7,i+1]/fin_df.iloc[7,i]
        debt_shift_ratio=fin_df.iloc[8,i+1]/fin_df.iloc[8,i]
        debt_ratio= fin_df.iloc[23,i+1]
        PER=fin_df.iloc[26,i+1]
        PBR=fin_df.iloc[28,i+1]
        PBR_shift_ratio_log=math.log(fin_df.iloc[28,i+1]/fin_df.iloc[28,i])
        reserve_ration=fin_df.iloc[24,i+1]
        ROE=fin_df.iloc[21,i+1]
        ROA = fin_df.iloc[22,i+1]
        OPM = fin_df.iloc[19,i+1]
        cash_dividend_payout=fin_df.iloc[31,i+1]
        #항목 더하기
        item_list =[sales_shift, operating_revenue_shift, net_revenue_shift, asset_shift_ratio, debt_ratio, debt_shift_ratio, PBR, PER, PBR_shift_ratio_log, OPM, reserve_ration, ROE, ROA, cash_dividend_payout]
        temp_list.extend(item_list)
        bal_df.loc[len(bal_df)] = temp_list
        
bal_df = bal_df.dropna()

bal_df
# Out:
# C:\Users\eaststate\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\eaststate\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in double_scalars
#        종목코드     해당년도    매출증감비율  영업이익증감비율  당기순이익증감비율  자산총계증감비율    부채비율  \
# 0    000070  2016/12  0.045475  0.010992  -0.004134  1.031907   71.26
# 1    000070  2017/12  0.026313 -0.013095   0.000652  1.033634   68.88
# 2    000070  2018/12  0.050745  0.012049   0.010714  1.011538   65.53
# 3    000070  2019/12 -0.021700 -0.017122  -0.011734  1.083198   76.87
# 4    000080  2016/12 -0.005043 -0.002915  -0.004372  0.982835  163.26
# ..      ...      ...       ...       ...        ...       ...     ...
# 783  282330  2019/12  0.093133  0.003885  -0.001532  1.465264  248.93
# 786  285130  2018/12  0.662611  0.028422  -0.003365  1.020079  168.87
# 787  285130  2019/12  0.029149  0.016950   0.010484  1.092731  196.60
# 791  294870  2019/12  0.307085  0.050383   0.039642  0.906691   97.58
# 795  298040  2019/12  0.430737  0.021605   0.003794  1.165564  303.92
#
#        부채증감비율   PBR     PER  log(PBR증감비율)    OPM    자본유보율    ROE   ROA  현금배당성향
# 0    1.034272  0.68   46.87     -0.302281   6.10  2881.71   1.68  2.09   68.45
# 1    1.013194  0.69   28.72      0.014599   4.12  2928.91   2.76  2.08   41.08
# 2    0.981814  0.43    9.95     -0.472906   5.40  3047.14   5.03  3.11   22.13
# 3    1.189115  0.37   19.25     -0.150282   3.19  3077.36   2.18  1.80   50.19
# 4    0.987499  1.14   39.18     -0.075986   6.56   271.98   2.94  1.12  163.80
# ..        ...   ...     ...           ...    ...      ...    ...   ...     ...
# 783  1.612863  4.70   19.35     -0.363460   3.31  3372.48  26.46  8.28   30.81
# 786  1.037338  1.32  151.41           inf   3.34  1020.34   0.87 -0.85   87.64
# 787  1.153281  1.18   79.34     -0.112117   5.63  1003.20   1.51  0.25   56.68
# 791  0.721365  0.53    2.89     -0.833729  13.08   916.87  20.30  8.92    5.31
# 795  1.190877  0.27   18.91     -0.465363   3.45  1910.73   1.45  0.43    0.00
#
# [685 rows x 16 columns]

# %%
bal_df.to_csv('raw.csv',encoding='cp949')
