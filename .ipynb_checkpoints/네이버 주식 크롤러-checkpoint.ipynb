# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import datetime
import os
import traceback
import time
import random
import requests
import bs4
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import csv

# %%
KOSPI200 = pd.read_csv("KOSPI200.csv", encoding='cp949')

code = []
for i in range(0, 200):
    a = str(KOSPI200["종목코드"][i])
    code.append("0"*(6-len(a)) + a)

KOSPI200["code"] = code
code
# Out:
# ['005930',
#  '000660',
#  '207940',
#  '035420',
#  '068270',
#  '051910',
#  '051900',
#  '005380',
#  '028260',
#  '006400',
#  '017670',
#  '035720',
#  '012330',
#  '005490',
#  '015760',
#  '055550',
#  '036570',
#  '105560',
#  '034730',
#  '018260',
#  '000270',
#  '033780',
#  '003550',
#  '090430',
#  '032830',
#  '000810',
#  '096770',
#  '066570',
#  '009150',
#  '086790',
#  '251270',
#  '010950',
#  '011170',
#  '010130',
#  '030200',
#  '316140',
#  '032640',
#  '009540',
#  '035250',
#  '271560',
#  '018880',
#  '002790',
#  '024110',
#  '021240',
#  '097950',
#  '034220',
#  '004990',
#  '000720',
#  '267250',
#  '086280',
#  '006800',
#  '078930',
#  '139480',
#  '000120',
#  '029780',
#  '012750',
#  '011070',
#  '008770',
#  '005830',
#  '000100',
#  '000210',
#  '128940',
#  '023530',
#  '007070',
#  '282330',
#  '071050',
#  '004020',
#  '161390',
#  '004170',
#  '010140',
#  '003410',
#  '005940',
#  '016360',
#  '047810',
#  '036460',
#  '001040',
#  '001450',
#  '011780',
#  '009830',
#  '241560',
#  '000080',
#  '028050',
#  '081660',
#  '006360',
#  '030000',
#  '007310',
#  '008560',
#  '003490',
#  '011790',
#  '008930',
#  '004370',
#  '020150',
#  '028670',
#  '042660',
#  '069960',
#  '003000',
#  '006280',
#  '026960',
#  '009240',
#  '047050',
#  '017800',
#  '138930',
#  '031430',
#  '064350',
#  '088350',
#  '004800',
#  '002380',
#  '000880',
#  '047040',
#  '051600',
#  '012450',
#  '001740',
#  '069620',
#  '009420',
#  '111770',
#  '006260',
#  '214320',
#  '010120',
#  '294870',
#  '000990',
#  '010620',
#  '204320',
#  '185750',
#  '114090',
#  '034020',
#  '005250',
#  '161890',
#  '004000',
#  '000670',
#  '006650',
#  '010060',
#  '014680',
#  '285130',
#  '000240',
#  '003520',
#  '192820',
#  '073240',
#  '042670',
#  '011210',
#  '001800',
#  '005300',
#  '057050',
#  '003240',
#  '120110',
#  '005440',
#  '001680',
#  '049770',
#  '010780',
#  '018250',
#  '170900',
#  '069260',
#  '000150',
#  '052690',
#  '008060',
#  '005850',
#  '192400',
#  '007570',
#  '005180',
#  '093370',
#  '005610',
#  '001060',
#  '103140',
#  '020000',
#  '115390',
#  '003850',
#  '079550',
#  '079160',
#  '071840',
#  '014820',
#  '002350',
#  '012630',
#  '006390',
#  '000640',
#  '064960',
#  '001120',
#  '105630',
#  '006120',
#  '108670',
#  '027410',
#  '002270',
#  '000070',
#  '019680',
#  '145990',
#  '004490',
#  '001230',
#  '025860',
#  '093050',
#  '014830',
#  '006840',
#  '002960',
#  '096760',
#  '001430',
#  '060980',
#  '001520',
#  '025540',
#  '002240',
#  '079430',
#  '003620',
#  '003920',
#  '298040']

# %%
#webdriver 객체생성
driver = webdriver.Chrome(ChromeDriverManager().install())
n=0

for i in code:
    URL ='https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd='+i+'&target=finsum_more'
    column_list=['항목','2015/12','2016/12','2017/12','2018/12','2019/12','2020/12(E)','2021/12(E)','2022/12(E)']
    with open('C:/Users/eaststate/Desktop/스마/재무/naver_finance_'+i+'.csv','w',-1,newline='') as f:
        w = csv.writer(f)
        w.writerow(column_list)
        
        #URL 접근
        driver.get(URL)
        driver.implicitly_wait(2)
        #연간으로 전환
        annual_link = driver.find_element_by_xpath("//a[@id='cns_Tab21']")
        annual_link.click()

        depth_1_tbody = driver.find_element_by_xpath("//div[3]//div[1]//div[1]//div[14]//table[2]//tbody")
        depth_1_thead = driver.find_element_by_xpath("//div[3]//div[1]//div[1]//div[14]//table[2]//tbody")
        depth_2_th
        depth_2_tr = depth_1_tbody.find_elements_by_tag_name("tr")
        #
        for td in depth_2_tr:
            row = td.text
            row_list = row.split(" ")
            for i in row_list:
                if i=='':
                    row_list.remove(i)
                if i=='':
                    row_list.remove(i)
            w.writerow(row_list)
        n=n+1
        print(str(n)+'개 완료')
# Out:
# [WDM] - Looking for [chromedriver 83.0.4103.39 win32] driver in cache
# [WDM] - File found in cache by path [C:\Users\eaststate\.wdm\drivers\chromedriver\83.0.4103.39\win32\chromedriver.exe]
# 1개 완료
# 2개 완료
# 3개 완료
# 4개 완료
# 5개 완료
# 6개 완료
# 7개 완료
# 8개 완료
# 9개 완료
# 10개 완료
# 11개 완료
# 12개 완료
# 13개 완료
# 14개 완료
# 15개 완료
# 16개 완료
# 17개 완료
# 18개 완료
# 19개 완료
# 20개 완료
# 21개 완료
# 22개 완료
# 23개 완료
# 24개 완료
# 25개 완료
# 26개 완료
# 27개 완료
# 28개 완료
# 29개 완료
# 30개 완료
# 31개 완료
# 32개 완료
# 33개 완료
# 34개 완료
# 35개 완료
# 36개 완료
# 37개 완료
# 38개 완료
# 39개 완료
# 40개 완료
# 41개 완료
# 42개 완료
# 43개 완료
# 44개 완료
# 45개 완료
# 46개 완료
# 47개 완료
# 48개 완료
# 49개 완료
# 50개 완료
# 51개 완료
# 52개 완료
# 53개 완료
# 54개 완료
# 55개 완료
# 56개 완료
# 57개 완료
# 58개 완료
# 59개 완료
# 60개 완료
# 61개 완료
# 62개 완료
# 63개 완료
# 64개 완료
# 65개 완료
# 66개 완료
# 67개 완료
# 68개 완료
# 69개 완료
# 70개 완료
# 71개 완료
# 72개 완료
# 73개 완료
# 74개 완료
# 75개 완료
# 76개 완료
# 77개 완료
# 78개 완료
# 79개 완료
# 80개 완료
# 81개 완료
# 82개 완료
# 83개 완료
# 84개 완료
# 85개 완료
# 86개 완료
# 87개 완료
# 88개 완료
# 89개 완료
# 90개 완료
# 91개 완료
# 92개 완료
# 93개 완료
# 94개 완료
# 95개 완료
# 96개 완료
# 97개 완료
# 98개 완료
# 99개 완료
# 100개 완료
# 101개 완료
# 102개 완료
# 103개 완료
# 104개 완료
# 105개 완료
# 106개 완료
# 107개 완료
# 108개 완료
# 109개 완료
# 110개 완료
# 111개 완료
# 112개 완료
# 113개 완료
# 114개 완료
# 115개 완료
# 116개 완료
# 117개 완료
# 118개 완료
# 119개 완료
# 120개 완료
# 121개 완료
# 122개 완료
# 123개 완료
# 124개 완료
# 125개 완료
# 126개 완료
# 127개 완료
# 128개 완료
# 129개 완료
# 130개 완료
# 131개 완료
# 132개 완료
# 133개 완료
# 134개 완료
# 135개 완료
# 136개 완료
# 137개 완료
# 138개 완료
# 139개 완료
# 140개 완료
# 141개 완료
# 142개 완료
# 143개 완료
# 144개 완료
# 145개 완료
# 146개 완료
# 147개 완료
# 148개 완료
# 149개 완료
# 150개 완료
# 151개 완료
# 152개 완료
# 153개 완료
# 154개 완료
# 155개 완료
# 156개 완료
# 157개 완료
# 158개 완료
# 159개 완료
# 160개 완료
# 161개 완료
# 162개 완료
# 163개 완료
# 164개 완료
# 165개 완료
# 166개 완료
# 167개 완료
# 168개 완료
# 169개 완료
# 170개 완료
# 171개 완료
# 172개 완료
# 173개 완료
# 174개 완료
# 175개 완료
# 176개 완료
# 177개 완료
# 178개 완료
# 179개 완료
# 180개 완료
# 181개 완료
# 182개 완료
# 183개 완료
# 184개 완료
# 185개 완료
# 186개 완료
# 187개 완료
# 188개 완료
# 189개 완료
# 190개 완료
# 191개 완료
# 192개 완료
# 193개 완료
# 194개 완료
# 195개 완료
# 196개 완료
# 197개 완료
# 198개 완료
# 199개 완료
# 200개 완료

# %%
URL ='https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=316140&target=finsum_more'
column_list=['']
#webdriver 객체생성
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
driver.implicitly_wait(2)

#URL 접근
driver.get(URL)
#연간으로 전환
annual_link = driver.find_element_by_xpath("//a[@id='cns_Tab21']")
annual_link.click()
depth_1_tbody = driver.find_element_by_xpath("//div[3]//div[1]//div[1]//div[14]")

html=driver.page_source
soup=BeautifulSoup(html,'html.parser')
div=soup.select_one("div#collapseSpecs")
table=pd.read_html(str(div))
print(table[0])
# Out:
# [WDM] - Looking for [chromedriver 83.0.4103.39 win32] driver in cache
# [WDM] - File found in cache by path [C:\Users\eaststate\.wdm\drivers\chromedriver\83.0.4103.39\win32\chromedriver.exe]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-03da8a5410e0> in <module>
#      16 soup=BeautifulSoup(html,'html.parser')
#      17 div=soup.select_one("div#collapseSpecs")
# ---> 18 table=pd.read_html(str(div))
#      19 print(table[0])
#      20
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ~\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#      44     if traceback == Ellipsis:
#      45         _, _, traceback = sys.exc_info()
# ---> 46     raise exc.with_traceback(traceback)
#      47
#      48
#
# ValueError: No tables found

# %%
depth_1_tbody = driver.find_element_by_xpath("//div[3]//div[1]//div[1]//div[14]//table[2]//tbody")
depth_2_tr = depth_1_tbody.find_elements_by_tag_name("tr")
for th in depth_2_th:
    head = th.text
    head_list = head.split(" ")
    print(head_list)
for td in depth_2_tr:
    row = td.text
    row_list = row.split(" ")
    if i=='':
        row_list.remove(i)
    if i=='':
        row_list.remove(i)
    print(row_list)
depth_2_tr

# %%
print(depth_1_tbody.text)
# Out:
# 매출액 192,332 188,250 168,871 167,309 172,788 173,376 182,488 188,516
# 영업이익 10,893 11,590 9,861 8,400 8,597 8,849 10,038 10,466
# 영업이익(발표기준) 10,893 11,590 9,861 8,400 8,597
# 세전계속사업이익 8,981 9,815 5,548 8,979 7,989 9,480 9,923 10,337
# 당기순이익 6,638 7,317 3,716 5,353 5,733 6,815 7,266 7,611
#   당기순이익(지배) 4,210 5,721 2,017 3,816 4,074 4,890 5,213 5,393
#   당기순이익(비지배) 2,428 1,596 1,699 1,537 1,659
# 자산총계 193,501 198,734 184,319 180,546 182,270 187,718 195,180 200,906
# 부채총계 119,595 117,488 99,590 97,628 95,120 94,845 96,371 95,811
# 자본총계 73,906 81,246 84,729 82,919 87,150 92,873 98,810 105,094
#   자본총계(지배) 57,203 63,290 64,676 62,741 66,626 70,930 75,397 79,939
#   자본총계(비지배) 16,703 17,956 20,053
# 자본금 5,573 5,573 5,573 5,573 5,573 5,571 5,571 5,571
# 영업활동현금흐름 5,960 10,865 5,144 2,495 4,789 6,761 6,302 7,160
# 투자활동현금흐름 -11,738 -7,752 -163 -920 -1,512 -1,627 -3,116 -2,532
# 재무활동현금흐름 307 -1,769 -3,809 -373 153 -2,228 -1,571 -2,156
# CAPEX 1,865 1,787 498 1,919 1,099 1,430 1,432 1,372
# FCF 4,095 9,079 4,646 576 3,690 4,584 3,953 4,468
# 이자발생부채 26,327 25,599 22,818 24,067 26,626
# 영업이익률 5.66 6.16 5.84 5.02 4.98 5.10 5.50 5.55
# 순이익률 3.45 3.89 2.20 3.20 3.32 3.93 3.98 4.04
# ROE(%) 7.65 9.50 3.15 5.99 6.30 7.11 7.12 6.94
# ROA(%) 3.53 3.73 1.94 2.93 3.16 3.68 3.80 3.84
# 부채비율 161.82 144.61 117.54 117.74 109.15 102.12 97.53 91.17
# 자본유보율 919.99 1,015.93 1,048.98 1,074.89 1,138.52
# EPS(원) 3,777 5,133 1,810 3,424 3,656 4,387 4,677 4,838
# PER(배) 7.56 8.34 20.06 15.95 11.57 7.38 6.93 6.70
# BPS(원) 51,324 56,786 58,029 56,293 59,778 63,640 67,648 71,723
# PBR(배) 0.56 0.75 0.63 0.97 0.71 0.51 0.48 0.45
# 현금DPS(원) 500 500 500 500 600 621 653 659
# 현금배당수익률 1.75 1.17 1.38 0.92 1.42 1.92 2.01 2.03
# 현금배당성향(%) 13.24 9.74 27.63 14.60 16.41 14.14 13.94 13.60
# 발행주식수(보통주) 111,355,765 111,355,765 111,355,765 111,355,765 111,355,765
